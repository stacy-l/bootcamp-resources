# %% [markdown]
# # Welcome to the Center for Computational Biology's Introduction to Programming for Bioinformatics bootcamp!

# %% [markdown]
# ## Agenda
# Welcome to the bootcamp!
# - Meet the teaching staff!
# - Lecture logistics (Zoom, Slack)
# - Topics and schedule
# - Getting started with Google Colaboratory

# %% [markdown]
# ## Meet the teaching staff!
# ### Your instructors are:
# (PLACEHOLDER until I figure out if we can make this section not just a ugly bullet point list...)
# - Stacy (Day 1)
# - Maya (Day 2)
# - Lucas (Day 3)
# - Adam (Day 4)
# - Andrew (Day 4, 5)
# - Shihab (Day 5)
#
# ### The TAs are:
# (PLACEHOLDER until I figure out if we can make this section not just a ugly bullet point list...)

# %% [markdown]
# ## Lecture logistics
# ### Browser
# We highly recommend using [Google Chrome](https://www.google.com/chrome/) to view and edit these notebooks. There shouldn't be an issue with using other browsers, but because Google Colaboratory (more on this soon) is a Google product, we expect that most functions will work best with Google Chrome.
#
# ### Zoom
#
# **BIG NOTE:** We need to overhaul this section to integrate info about the Slack channel we're creating. Participants should be *strongly encouraged* to sign up for Slack before the bootcamp, but we should anticipate that folks may not have done that: a quick walk-through of Slack should suffice for showing that it is not a super optional part of bootcamp.
#
# * Make sure you have Zoom desktop or mobile installed (instead of using it from a browser).
#   * Double-check that you have version 5.3.0 or higher: we need this to use self-select breakout rooms. If you're not sure how to do that, click [here](https://support.zoom.us/hc/en-us/articles/201362393-Viewing-the-Zoom-version-number).
# * **During interactive lecture**: Please turn your video off during lecture to minimize lagginess.
#   * TAs will monitor the Zoom chat for lecture-related questions.
#   * Resources posted in the Zoom chat will be posted to Slack in the #resources channel. (More on Slack in a second.)
# * **During coding exercises**: You will be randomly assigned into a smaller breakout room headed by one of the teaching staff.
#   * Videos are encouraged, but not required.
#   * **Do you prefer to work alone?** We have a "quiet time" breakout room for people who would like to work on their own: you can move into this room using the Breakout Rooms button on your Zoom toolbar.
#   * **Are you taking the course with your lab/team?** Feel free to move between breakout rooms to join colleagues/peers you're taking the course with, we encourage collaboration!
#
# ### Slack
# Slack is an interactive workspace that allows for us to share resources, provide support, and otherwise communicate with you all during the workshop. If you haven't signed up already, click **[****FILL IN LATER****]** to access or join our workspace.
#
# * **Have an issue with Zoom, Google Drive, or your Colab notebook?**: Let us know in the #tech-support channel, and one of the teaching staff will get back to you ASAP.
# * **Looking for a link you saw in Zoom chat?**: Check the **[SOMETHING HERE]** channel. **[****I am thinking we either have a channel by day, or a single "resources" channel?****]**

# %% [markdown]
# ## Topics and schedule

# %% [markdown]
# ### What are you going to learn?
#
# You are going to learn Python! 🐍
#
# Python is a simple and powerful programming language that is used for many applications, from simple tasks to large software development projects. It has become popular as both a first language for beginning students and in everyday use advanced programmers.
#
# Our goal is to show you how to apply programming to the problems and tasks that you face in the lab – in short, we'll be teaching you **basic bioinformatics**. By the end of this course, you will be able to do the following:
# * Parse and read in data from various biological file formats.
# * Write custom functions for analyzing your data.
# * Learn how to find and use different Python packages for analyzing your data.
# * Understand how to construct scripts to automate your data analysis.
# * Make publication-quality figures with your data.
#
# Our aim is for you to leave this course with a sufficiently generalized knowledge of programming (and the confidence to read the manuals) that you will be able to apply your skills to whatever you happen to be working on.

# %% [markdown]
# ### What are you *not* going to learn?
#
# With only one week to teach this course, there are many topics that we are not going to cover. :(
#
# We will focus on basic skills that can be employed by biologists at all levels: manage and handle large data sets, automating and speeding up tasks, efficiently use existing software packages to answer biological questions, build pipelines for data analysis and management, and perform basic statistical tests and analysis.
#
# This means we will *not* delve into more complex topics like software development, algorithms, or deploying code on computing clusters. We're happy to refer you to other resources or programs that may be useful for these topics, but **our goal is to get you started with the basics so that you can direct *your own* learning.**

# %% [markdown]
# ### Weekly Schedule
# That being said, we do have a defined list of topics that we'll be going through day by day.<br>
# **[**** MAKE SURE THIS IS UP TO DATE BY TIME OF LECTURE ****]**<br><br>
# Monday, June 14 (today): *Introduction to variables, types, functions, and methods*<br>
# Tuesday, June 15: *Control flow and logic, introduction to data structures*<br>
# Wednesday, June 16: *More on data structures, file input/output/writing*<br>
# Thursday, June 17: *Numpy, Scipy, and Pandas for biological data science*<br>
# Friday, June 18: *Creating figures and plots, final wrap-up mini-project*<br>

# %% [markdown]
# ### Daily Schedule
#
# Each day is broken up into two interactive lecture modules: instructors will share their screens and lecture while working through the notebook. You are *strongly encouraged* to work through your copy of the notebook side-by-side! (More details on that in a few minutes.)
#
# Below is a rough outline of the schedule: the amount of time we spend on each segment will vary.
#
# **Start at 9am:**
#
# 9 - 10am: Interactive lecture<br>
# 10 - 10:45am: Complementary coding exercises; solution walkthrough<br>
# 10:45 - 11:45am: Interactive lecture<br>
# 11:45 - 12:30pm: Complementary coding exercises; solution walkthrough<br>
#
# **Lunch from 12:30-1:30pm**: You can either stay on Zoom or leave and rejoin.
#
# 1:30 - 2:30pm: Interactive lecture<br>
# 2:30 - 3:15pm: Complementary coding exercises; solution walkthrough<br>
# 3:15 - 4:15pm: Interactive lecture<br>
# 4:15 - 5:00pm: Complementary coding exercises; solution walkthrough<br>
#
# **End at 5pm!**
#
# We *will* have cues for short 5-minute breaks throughout the day, but please feel free to take breaks at your own discretion. :)

# %% [markdown]
# ## Getting started with Google Colaboratory
#
# During the bootcamp, you'll be writing and executing your code with a tool called **Google Colaboratory** (Google Colab for short).
#
# Colab is like an interactive coding notebook: you can write chunks of text just like you would with a word document or Google Doc, interspersed with chunks of Python code. Colab is especially nifty because it allows you to run your code using Google's cloud computing resources instead of your own computer's hardware. What's more, your code is saved to the cloud in real time, just like with the other tools in Google Drive.
#
# Throughout the bootcamp, the instructors will be working on their copy of the notebook. You can (and should!) work through your own copy of notebook side by side in order to get the most out of the bootcamp. No worries about mistakes or overwriting: you can always re-download a fresh copy of the materials here **[**** INSERT LINK WHEN READY ****]** or re-download an old copy of your notebook from Google Drive.
#
# Let's get started by familiarizing ourselves with the basic tools in Colab, many of which may be familiar to you if you've used Google Drive products (Docs, etc) before.

# %% [markdown]
# ### Connecting to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# ?drive.mount

# %% [markdown]
# ### Using the Table of Contents
#
# The Table of Contents is an invaluable tool for flipping through the notebooks we'll be using each day of the bootcamp. You can access the Table of Contents by clicking on the topmost button of the *left hand side toolbar*.
#
# Try clicking on the "Taking notes" heading, which will bring you to the section below.

# %% [markdown]
# ### Taking notes
#
# Much like with live lectures, you'll probably want to take notes as we go. Luckily, Colab allows you to write notes in a number of different ways. Let's start by editing some text within an already established text cell.
#
# Single click on the sentence below to reveal the text cell. Afterwards, double click to fill in the blank, then hold down Shift + Enter to save your changes.

# %% [markdown]
# > Today is [______], June 14th.

# %% [markdown]
# You can edit any of the text cells in Colab using this method. Colab supports basic formatting like **bold**, *italic*, and even
#
#
# *   bullet
# *   points!
#
#
# Alternatively, you can *create* new text cells anywhere you want. Try single clicking this cell, then using the [+ Text] button in the top toolbar to create a new text cell.

# %% [markdown]
# Your text cell should appear right above this text cell.

# %% [markdown]
# ### Connect to a runtime
# A *runtime* in Google Colab is a computing environment that allows us to execute the code in our notebook.
#
# Click on the "Connect" button on the *right hand side of the top toolbar*. You should see it flash through a few different status messages. After the runtime is connected, you should see a green checkmark and two bars labeled "RAM" and "Disk".

# %% [markdown]
# ### Running code cells
#
# Now, let's try running some code. Take a look at the code cell below, which explains what "comments" are. When you're ready, hover your cursor over the cell and press the "play" button on the left hand side of the cell.

# %%
# This is a "comment": programmers use comments to annotate their code.
# The foundation of good code is good annotation.
# We'll write comments in our code, and you should write comments in yours as you go along!

print("Comments aren't visible in the output of the code cell: they're just for the reader!")
# print("That means that this bit of code won't actually run!")
# When you run this cell, the output will appear in a separate section below.
print("You can put comments in between or after lines of code, and they won't be visible.") # Look, no comment!
# Out:
# Comments aren't visible in the output of the code cell: they're just for the reader!
# You can put comments in between or after lines of code, and they won't be visible.

# %% [markdown]
# You can edit and run code cells just like you would with text cells.

# %%
# As you saw above, "print" is a built-in Python function that prints some text to the cell's output.
# Edit this cell and use print to print "Hello world!".

# Enter your code below:

# %% [markdown]
# Congratulations! You've just taken your first step to writing code in Python. 🐍

# %% [markdown]
# # Exercises
# All of the following exercises should be done in the **terminal**. We have not started using Python yet.

# %% [markdown]
# ### 1) Navigate to python folder
# Navigate to your python bootcamp lecture 1 morning session folder using a combination of `pwd`, `ls`, and `cd`. Practice using:
# - relative and absolute paths
# - TAB key to autocomplete

# %% [markdown]
# ### 2) Look inside a file
# Inside this lecture's folder, there is a file named "Yeast_Genome.fasta". Use `less` to take a look at its contents. Does the sequence `GATTACA` ever appear in this genome?

# %% [markdown]
# ### 3) Open the next notebook
# Open the notebook for lecture 1.1.2 - Variables and Types and let me know when you are there!
